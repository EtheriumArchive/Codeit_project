# %%
import pandas as pd
import numpy as np
from pathlib import Path

# 0) 경로 세팅

ROOT = Path.cwd()
DATA_DIR = ROOT / "clean_vote_ver2"
OUT_DIR  = ROOT / "analysis_out"

HACKLE_PATH   = DATA_DIR / "processed_hackle_merge.csv"
PAY_PATH      = DATA_DIR / "processed_accounts_paymenthistory.csv"
FAILPAY_PATH  = DATA_DIR / "processed_accounts_failpaymenthistory.csv"

print("HACKLE:", HACKLE_PATH.exists(), HACKLE_PATH)
print("PAY  :", PAY_PATH.exists(), PAY_PATH)
print("FAIL :", FAILPAY_PATH.exists(), FAILPAY_PATH)


# 1) 큰 파일 처리 옵션

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 200)


CHUNK = 500_000
# Out:
# HACKLE: True /Users/10moo/260128_proj/clean_vote_ver2/processed_hackle_merge.csv
# PAY  : True /Users/10moo/260128_proj/clean_vote_ver2/processed_accounts_paymenthistory.csv
# FAIL : True /Users/10moo/260128_proj/clean_vote_ver2/processed_accounts_failpaymenthistory.csv

# %%
hackle = pd.read_csv("clean_vote_ver2/processed_hackle_merge.csv")
pay   = pd.read_csv("clean_vote_ver2/processed_accounts_paymenthistory.csv")
fail  = pd.read_csv("clean_vote_ver2/processed_accounts_failpaymenthistory.csv")
# Out:
# /var/folders/v1/k2x8lm750mbb_z0sj197vzrh0000gn/T/ipykernel_27624/1640665223.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   hackle = pd.read_csv("clean_vote_ver2/processed_hackle_merge.csv")

# %%
# 하트 이상치
# 기준 임의 설정
### 10만개 이상 11명
# 100만개 이상 4명
# 1000만개 이상 2명
# 1억개 이상 2명
# 10억개 이상 0명

THRESH = 100000

out_users = (hackle.loc[hackle["heart_balance"] >= THRESH, "user_id"].dropna().astype(str).unique())

print("이상치 유저 수:", len(out_users))
out_users[:10]
# Out:
# 이상치 유저 수: 11
# array(['1577938.0', '914589.0', '1577954.0', '1437875.0', '833041.0',
#        '849763.0', '1290502.0', '967442.0', '1577930.0', '838541.0'],
#       dtype=object)

# %%
# 11명 유저들의 결제기록, 결제 실패기록
pay_out = pay[pay["user_id"].isin(heart_out_users)]
fail_out = fail[fail["user_id"].isin(heart_out_users)]

print("결제 기록 수:", len(pay_out))
print("실패 기록 수:", len(fail_out))

display(pay_out.head(10))
fail_out.tail()
# Out:
# 결제 기록 수: 9
# 실패 기록 수: 0
#        user_id   productId phone_type           created_at
# 1918    838541   heart.200          I  2023-05-14 03:36:19
# 3132    838541   heart.777          I  2023-05-14 05:00:59
# 5757    833041  heart.4000          I  2023-05-14 07:59:46
# 13371   833041  heart.4000          I  2023-05-15 01:50:06
# 26856   838541   heart.200          I  2023-05-16 16:49:01
# 89610  1290502   heart.777          A  2023-06-23 06:48:40
# 89668  1563520   heart.777          A  2023-06-24 07:01:41
# 90060  1577930   heart.777          A  2023-07-09 07:27:17
# 90062  1577938   heart.777          I  2023-07-09 07:48:21
# Empty DataFrame
# Columns: [id, user_id, productId, phone_type, created_at]
# Index: []

# %%
# 활동 로그
out_logs = hackle[hackle["user_id"].isin(heart_out_users)] \
    .sort_values("event_datetime", ascending=False)

out_logs.head()
# 너무 많음
# Out:
#                                     session_id    user_id language   osname osversion versionname                             device_id                              event_id       event_datetime  \
# 17945534  ea0e4dd9-8447-4580-a140-6869d6ff39a5  1290502.0       ko  Android        13       2.0.0  ea0e4dd9-8447-4580-a140-6869d6ff39a5  59a31307-1504-4882-be22-f02d594f94d0  2023-08-10 23:24:18
# 17945552  ea0e4dd9-8447-4580-a140-6869d6ff39a5  1290502.0       ko  Android        13       2.0.0  ea0e4dd9-8447-4580-a140-6869d6ff39a5  f6568435-994c-4bc5-8391-ac4c50e8bff1  2023-08-10 23:24:18
# 11395625  ea0e4dd9-8447-4580-a140-6869d6ff39a5  1290502.0       ko  Android        13       2.0.5  ea0e4dd9-8447-4580-a140-6869d6ff39a5  511be6f2-eb39-4108-8f98-9ec63d382a48  2023-08-10 23:24:18
# 17945537  ea0e4dd9-8447-4580-a140-6869d6ff39a5  1290502.0       ko  Android        13       2.0.0  ea0e4dd9-8447-4580-a140-6869d6ff39a5  8ea7b0c7-46d7-4a44-be0e-47e21c83696c  2023-08-10 23:24:18
# 11395627  ea0e4dd9-8447-4580-a140-6869d6ff39a5  1290502.0       ko  Android        13       2.0.5  ea0e4dd9-8447-4580-a140-6869d6ff39a5  59a31307-1504-4882-be22-f02d594f94d0  2023-08-10 23:24:18
#
#                                 event_key item_name page_name  friend_count  votes_count  heart_balance  question_id
# 17945534                view_timeline_tap       NaN       NaN          54.0        140.0       151907.0          NaN
# 17945552                 view_profile_tap       NaN       NaN          54.0        140.0       151907.0          NaN
# 11395625  click_bottom_navigation_profile       NaN       NaN          54.0        140.0       151907.0          NaN
# 17945537                     view_lab_tap       NaN       NaN          54.0        140.0       151907.0          NaN
# 11395627                view_timeline_tap       NaN       NaN          54.0        140.0       151907.0          NaN

# %%
# 로그 수, 최대 하트, 최소 하트 요약
def show_user_log(user_id):
    user_log = hackle[hackle["user_id"] == user_id] \
        .sort_values("event_datetime")

    print(f"\n===== USER {user_id} =====")
    print("총 이벤트 수:", len(user_log))
    print("최대 하트:", user_log["heart_balance"].max())
    print("최소 하트:", user_log["heart_balance"].min())

    user_log[["event_datetime", "event_key", "heart_balance", "friend_count", "votes_count", "item_name", "page_name"]].tail(30)

# %%
show_user_log(heart_out_users[10])
# 최대 하트 수가 왜 20만개인 사람이지?
# 7억개, 8억개 유저는?
# 누적기록이었나?
# Out:
# ===== USER 1563520.0 =====
# 총 이벤트 수: 40
# 최대 하트: 208894.0
# 최소 하트: 208894.0

# %%
hackle["heart_balance"].max()
# 8억개가 맞음
# Out:
# np.float64(884999804.0)

# %%
# 8억개 유저 정보
hackle.loc[hackle["heart_balance"].idxmax()]
# Out:
# session_id                NnVWxmwjHcfnMENN9y4SrTPfcG82
# user_id                                       833041.0
# language                                         ko-KR
# osname                                             iOS
# osversion                                       16.5.1
# versionname                                      2.0.5
# device_id         420F81D6-4206-4D72-B42D-207341327899
# event_id          01a583d7-b2b2-490b-96f6-1645b172ac0e
# event_datetime                     2023-07-24 20:58:40
# event_key                               $session_start
# item_name                                          NaN
# page_name                                          NaN
# friend_count                                      65.0
# votes_count                                       97.0
# heart_balance                              884999804.0
# question_id                                        NaN
# Name: 7323975, dtype: object

# %%
# 8억개 유저 아이디 행동 로그
uid = hackle.loc[hackle["heart_balance"].idxmax(), "user_id"]

hackle[hackle["user_id"] == uid] \
    .sort_values("event_datetime") \
    [["user_id", "event_datetime", "event_key", "heart_balance"]]
# Out:
#            user_id       event_datetime                        event_key  heart_balance
# 10310396  833041.0  2023-07-18 07:28:20                   $session_start    884999804.0
# 10310427  833041.0  2023-07-18 07:28:20                       launch_app    884999804.0
# 7323988   833041.0  2023-07-18 07:28:20                   $session_start    884999804.0
# 7324019   833041.0  2023-07-18 07:28:20                       launch_app    884999804.0
# 7324012   833041.0  2023-07-18 07:28:24                     view_lab_tap    884999804.0
# ...            ...                  ...                              ...            ...
# 7323978   833041.0  2023-08-02 22:26:50                     view_lab_tap    884999804.0
# 7324039   833041.0  2023-08-02 22:26:50  click_bottom_navigation_profile    884999804.0
# 7324094   833041.0  2023-08-02 22:26:50                 view_profile_tap    884999804.0
# 10310386  833041.0  2023-08-02 22:26:50                     view_lab_tap    884999804.0
# 10310502  833041.0  2023-08-02 22:26:50                 view_profile_tap    884999804.0
#
# [268 rows x 4 columns]

# %%
# 구매기록 2건 밖에 없음
pay[pay["user_id"] == max_user]
# Out:
#        user_id   productId phone_type           created_at
# 5757    833041  heart.4000          I  2023-05-14 07:59:46
# 13371   833041  heart.4000          I  2023-05-15 01:50:06

# %%
# 구매 실패기록은 없음
fail[fail["user_id"] == max_user]
# Out:
# Empty DataFrame
# Columns: [id, user_id, productId, phone_type, created_at]
# Index: []

# %%
# 이 사람 친구 수는 65명
hackle[hackle["user_id"] == max_user]["friend_count"].max()
# Out:
# np.float64(65.0)

# %% [markdown]
# - 하트 기록이 고정되어있는게 아니라, 변화하는 값인거였슨...!
# - 그럼 하트 증가/감소폭이 급한 사람을 찾아야 함

# %%
# 유저별 최고 하트 수와 최종 하트 수 비교

target_users = out_users

target_df = hackle[hackle["user_id"].astype(str).isin(target_users)].copy()
target_df = target_df.sort_values(["user_id", "event_datetime"])

summary = (
    target_df.groupby("user_id")
    .agg(
        event_cnt=("event_id", "count"),
        heart_max=("heart_balance", "max"),
        heart_avg=("heart_balance", "mean"),
        last_dt=("event_datetime", "max"),
    )
    .reset_index()
)

# 유저별 최종 heart_balance
last_heart = (
    target_df.dropna(subset=["event_datetime"])
    .groupby("user_id")
    .tail(1)[["user_id", "heart_balance"]]
    .rename(columns={"heart_balance": "heart_last"})
)

summary = summary.merge(last_heart, on="user_id", how="left") \
                 .sort_values("heart_max", ascending=False)

summary.head(15)
# 7억개인 사람 최종 하트 수가 엄청 적다
# Out:
#       user_id  event_cnt    heart_max     heart_avg              last_dt   heart_last
# 0    833041.0        268  884999804.0  8.849998e+08  2023-08-02 22:26:50  884999804.0
# 4    967442.0         45  703126260.0  4.458881e+08  2023-08-05 18:29:19       8517.0
# 2    849763.0       2702    9991115.0  6.527275e+06  2023-08-10 17:08:48    9991115.0
# 6   1437875.0       3129    9991115.0  8.354790e+06  2023-08-10 17:08:48    9991115.0
# 3    914589.0       1022     263783.0  2.636372e+05  2023-08-10 18:16:19     263783.0
# 7   1563520.0         40     208894.0  2.088940e+05  2023-07-25 22:13:16     208894.0
# 5   1290502.0         66     151907.0  1.519070e+05  2023-08-10 23:24:18     151907.0
# 1    838541.0        568     100142.0  6.917130e+04  2023-08-04 19:22:15      95474.0
# 8   1577930.0        568     100142.0  6.917130e+04  2023-08-04 19:22:15      95474.0
# 9   1577938.0       1136     100142.0  6.917130e+04  2023-08-04 19:22:15      95474.0
# 10  1577954.0       1394     100142.0  7.427011e+04  2023-08-10 13:46:58      95482.0

# %%
# 하트 변화량

hackle = hackle.sort_values(["user_id", "event_datetime"])

# 직전 값 대비 변화량
hackle["heart_diff"] = (
    hackle.groupby("user_id")["heart_balance"]
    .diff()
)

hackle[["user_id","event_datetime","heart_balance","heart_diff"]].head()
# Out:
#            user_id       event_datetime  heart_balance  heart_diff
# 16377238  831962.0  2023-07-20 18:50:09            NaN         NaN
# 16377244  831962.0  2023-07-20 18:50:09            NaN         NaN
# 16377243  831962.0  2023-07-20 18:50:14            NaN         NaN
# 16377249  831962.0  2023-07-20 18:50:14            NaN         NaN
# 16377240  831962.0  2023-07-20 18:50:16            NaN         NaN

# %%
# 왜 다 null이 나오는건지?
# 하트 결측치
hackle["heart_balance"].isna().sum()
# Out:
# np.int64(875889)

# %%
# 0) 정렬
hackle = hackle.sort_values(["user_id", "event_datetime"])

# 1) heart_balance 있는 행만 따로 뽑기
hb = hackle.loc[hackle["heart_balance"].notna(), ["user_id", "event_datetime", "event_key", "heart_balance"]].copy()

# 2) diff 계산
hb["heart_diff"] = hb.groupby("user_id")["heart_balance"].diff()

# 3) 한 유저만 확인
uid = hb["user_id"].iloc[0]
hb[hb["user_id"] == uid].head(20)
# Out:
#            user_id       event_datetime                        event_key  heart_balance  heart_diff
# 16377252  831962.0  2023-07-20 18:50:17      click_bottom_navigation_lab         1982.0         NaN
# 16377254  831962.0  2023-07-20 18:50:17                     view_lab_tap         1982.0         0.0
# 16377241  831962.0  2023-07-20 18:50:20  click_bottom_navigation_profile         1982.0         0.0
# 16377237  831962.0  2023-07-20 18:50:24      click_bottom_navigation_lab         1982.0         0.0
# 16377245  831962.0  2023-07-20 18:50:24                     view_lab_tap         1982.0         0.0
# 16377248  831962.0  2023-07-20 18:50:25  click_bottom_navigation_profile         1982.0         0.0
# 16377246  831962.0  2023-07-20 18:50:26                     view_lab_tap         1982.0         0.0
# 16377250  831962.0  2023-07-20 18:50:26      click_bottom_navigation_lab         1982.0         0.0
# 16377242  831962.0  2023-07-20 19:28:36  click_bottom_navigation_profile         1982.0         0.0
# 16377247  831962.0  2023-07-20 19:28:36                     view_lab_tap         1982.0         0.0
# 16377239  831962.0  2023-07-20 19:28:39      click_bottom_navigation_lab         1982.0         0.0
# 16377251  831962.0  2023-07-20 19:28:39  click_bottom_navigation_profile         1982.0         0.0
# 16377253  831962.0  2023-07-20 19:28:39                     view_lab_tap         1982.0         0.0

# %%
# 4000 이상 점프한 사람
# 가장 비싼 하트가 4000이니까
TH = 4001

jump_users = (hb.loc[hb["heart_diff"].abs() >= TH, ["user_id"]])

jump_users.head(20)
# Out:
#            user_id
# 5766176   836487.0
# 14430244  838541.0
# 14430133  838541.0
# 14430344  838541.0
# 14430226  838541.0
# 5967079   843185.0
# 2501776   849244.0
# 16323300  849763.0
# 8295626   849763.0
# 16323299  849763.0
# 8296035   849763.0
# 19400741  849763.0
# 8295952   849763.0
# 8295495   849763.0
# 17439688  849763.0
# 8295641   849763.0
# 17439971  849763.0
# 8295465   849763.0
# 17439807  849763.0
# 8296235   849763.0

# %%
# 4001 이상 하트가 변화한 건이 814건
len(jump_users)
# Out:
# 814

# %%
TH = 4001

hackle = hackle.sort_values(["user_id", "event_datetime"])

hb = hackle.loc[hackle["heart_balance"].notna(),["user_id", "event_datetime", "event_key", "heart_balance"]].copy()

hb["heart_diff"] = hb.groupby("user_id")["heart_balance"].diff()

jump_users = (hb.loc[hb["heart_diff"].abs() >= TH, "user_id"].dropna().astype("int64").unique())

print("점프 유저 수:", len(jump_users))
jump_users[:50]
# Out:
# 점프 유저 수: 388
# array([836487, 838541, 843185, 849244, 849763, 852859, 859913, 860594,
#        867575, 879916, 885945, 889629, 893651, 896349, 897148, 901798,
#        902108, 904885, 905606, 909118, 913652, 913764, 917305, 924010,
#        928431, 929393, 929425, 934103, 934983, 935764, 936072, 936203,
#        937905, 939259, 940302, 945154, 945387, 955817, 955844, 958443,
#        959102, 959305, 961722, 962413, 962619, 965306, 965867, 966185,
#        966555, 967442])

# %%
TH = 4001

jump_logs = (
    hb.loc[hb["heart_diff"].abs() >= TH,
           ["user_id","event_datetime","event_key","heart_balance","heart_diff"]]
    .sort_values(["user_id","event_datetime"])
)

jump_logs["user_id"] = jump_logs["user_id"].astype("int64")

print("점프 로그 수:", len(jump_logs))
jump_logs.head(50)
# Out:
# 점프 로그 수: 814
#           user_id       event_datetime                        event_key  heart_balance  heart_diff
# 5766176    836487  2023-07-26 23:58:14                       launch_app          613.0     -4393.0
# 14430244   838541  2023-07-21 19:15:25                   $session_start         1844.0    -95059.0
# 14430133   838541  2023-07-21 19:15:26  click_bottom_navigation_profile       100142.0     98298.0
# 14430344   838541  2023-07-21 19:17:42                   $session_start          975.0    -99167.0
# 14430226   838541  2023-07-23 17:41:28      click_bottom_navigation_lab        96953.0     95760.0
# 5967079    843185  2023-08-10 13:05:27                       launch_app         1646.0     -4687.0
# 2501776    849244  2023-07-27 03:13:56                view_timeline_tap        14319.0      4971.0
# 16323300   849763  2023-07-19 01:00:49                   $session_start          766.0  -9990125.0
# 8295626    849763  2023-07-19 01:46:42                   $session_start      9990891.0   9990125.0
# 16323299   849763  2023-07-19 19:50:17                   $session_start          766.0  -9990125.0
# 8296035    849763  2023-07-19 20:09:29                   $session_start      9990891.0   9990125.0
# 19400741   849763  2023-07-20 16:00:50  click_bottom_navigation_profile          766.0  -9990125.0
# 8295952    849763  2023-07-20 18:45:52                   $session_start      9990891.0   9990125.0
# 8295495    849763  2023-07-21 01:30:51                   $session_start          766.0  -9990125.0
# 17439688   849763  2023-07-21 02:33:38                   $session_start        96890.0     96124.0
# 8295641    849763  2023-07-21 02:36:14                       launch_app          766.0    -96137.0
# 17439971   849763  2023-07-21 02:39:29                     $session_end        96903.0     96124.0
# 8295465    849763  2023-07-21 02:39:35                     view_lab_tap          779.0    -96124.0
# 17439807   849763  2023-07-21 03:11:26                   $session_start        96903.0     96124.0
# 8296235    849763  2023-07-21 03:44:50                       launch_app          779.0    -96124.0
# 17440051   849763  2023-07-21 04:15:47                   $session_start        96903.0     96124.0
# 8295929    849763  2023-07-21 04:16:25                     view_lab_tap          779.0    -96124.0
# 17439772   849763  2023-07-21 04:40:11                     $session_end        96903.0     96124.0
# 8296154    849763  2023-07-21 14:52:55                       launch_app          779.0    -96124.0
# 17439761   849763  2023-07-21 16:53:35                   $session_start        96903.0     96124.0
# 8295450    849763  2023-07-21 19:14:57                   $session_start          779.0    -96124.0
# 17439716   849763  2023-07-21 19:15:12  click_bottom_navigation_profile        96903.0     96124.0
# 8295822    849763  2023-07-21 19:15:20                view_timeline_tap      9990891.0   9893988.0
# 17439826   849763  2023-07-21 19:15:20                   $session_start        96903.0  -9893988.0
# 17439758   849763  2023-07-21 19:15:25                   $session_start         1844.0    -95059.0
# 17439647   849763  2023-07-21 19:15:26  click_bottom_navigation_profile       100142.0     98298.0
# 8295444    849763  2023-07-21 19:17:21                     view_lab_tap      9990891.0   9890749.0
# 17439683   849763  2023-07-21 19:17:24  click_bottom_navigation_profile       100142.0  -9890749.0
# 17439858   849763  2023-07-21 19:17:42                   $session_start          975.0    -99167.0
# 8296165    849763  2023-07-21 20:01:30                view_timeline_tap      9990891.0   9989698.0
# 17439964   849763  2023-07-21 20:11:42      click_bottom_navigation_lab         1193.0  -9989698.0
# 8296444    849763  2023-07-21 21:28:02                   $session_start      9990891.0   9989698.0
# 17439642   849763  2023-07-21 22:38:16                       launch_app         1193.0  -9989698.0
# 8296284    849763  2023-07-21 23:38:21                   $session_start      9990891.0   9989698.0
# 17439895   849763  2023-07-21 23:44:29                view_timeline_tap         1193.0  -9989698.0
# 8296399    849763  2023-07-21 23:47:40                       launch_app      9990891.0   9989698.0
# 17439976   849763  2023-07-22 00:40:03                   $session_start         1193.0  -9989698.0
# 8295549    849763  2023-07-22 00:51:52                view_timeline_tap      9990891.0   9989698.0
# 17439668   849763  2023-07-22 04:52:58                       launch_app         1193.0  -9989698.0
# 8295870    849763  2023-07-22 05:25:13                     $session_end      9990891.0   9989698.0
# 17439851   849763  2023-07-22 14:10:09                   $session_start         1193.0  -9989698.0
# 8295724    849763  2023-07-22 14:12:23                   $session_start      9990891.0   9989698.0
# 17439745   849763  2023-07-22 15:46:26                   $session_start         1193.0  -9989698.0
# 8296253    849763  2023-07-22 15:46:30                     $session_end      9990891.0   9989698.0
# 17439959   849763  2023-07-22 15:46:48                     $session_end         1193.0  -9989698.0

# %%
# 진짜 직전 로그 대비 변화량이 맞는지
uid = 849763

u = hb[hb["user_id"] == uid].copy()
u["heart_balance"].value_counts().head(20)
# 이건 그냥 해당 값이 몇 번 등장하는지 카운트
# Out:
# heart_balance
# 9990891.0    908
# 779.0        305
# 9990927.0    202
# 97007.0      188
# 9991027.0    144
# 1193.0       137
# 9990993.0    112
# 96953.0      108
# 9991052.0     90
# 9991115.0     80
# 766.0         73
# 9991105.0     64
# 9990981.0     54
# 96977.0       40
# 9990864.0     38
# 96903.0       34
# 9990988.0     24
# 9991019.0     20
# 514.0         14
# 100142.0      13
# Name: count, dtype: int64

# %%
# 
u = hb[hb["user_id"] == 849763].copy()

u = u.sort_values(["event_datetime"])

u[["event_datetime", "event_key", "heart_balance"]].head(60)
# Out:
#                event_datetime                          event_key  heart_balance
# 8295627   2023-07-18 00:24:39   click_bottom_navigation_timeline      9990864.0
# 14436270  2023-07-18 00:24:39   click_bottom_navigation_timeline      9990864.0
# 8295507   2023-07-18 00:24:40  click_bottom_navigation_questions      9990864.0
# 8295986   2023-07-18 00:24:40        click_bottom_navigation_lab      9990864.0
# 14436150  2023-07-18 00:24:40  click_bottom_navigation_questions      9990864.0
# 14436629  2023-07-18 00:24:40        click_bottom_navigation_lab      9990864.0
# 8295767   2023-07-18 00:24:41                       view_lab_tap      9990864.0
# 14436410  2023-07-18 00:24:41                       view_lab_tap      9990864.0
# 14436760  2023-07-18 01:02:29   click_bottom_navigation_timeline      9990864.0
# 14436537  2023-07-18 01:02:29  click_bottom_navigation_questions      9990864.0
# 8295894   2023-07-18 01:02:29  click_bottom_navigation_questions      9990864.0
# 8296117   2023-07-18 01:02:29   click_bottom_navigation_timeline      9990864.0
# 8295720   2023-07-18 01:02:30                       view_lab_tap      9990864.0
# 8295732   2023-07-18 01:02:30        click_bottom_navigation_lab      9990864.0
# 14436363  2023-07-18 01:02:30                       view_lab_tap      9990864.0
# 14436375  2023-07-18 01:02:30        click_bottom_navigation_lab      9990864.0
# 8296215   2023-07-18 01:27:11        click_bottom_navigation_lab      9990864.0
# 14436858  2023-07-18 01:27:11        click_bottom_navigation_lab      9990864.0
# 14436729  2023-07-18 01:27:15   click_bottom_navigation_timeline      9990864.0
# 8296086   2023-07-18 01:27:15   click_bottom_navigation_timeline      9990864.0
# 8296290   2023-07-18 01:27:17  click_bottom_navigation_questions      9990864.0
# 14436933  2023-07-18 01:27:17  click_bottom_navigation_questions      9990864.0
# 8295556   2023-07-18 01:27:18          click_appbar_alarm_center      9990864.0
# 14436199  2023-07-18 01:27:18          click_appbar_alarm_center      9990864.0
# 14436776  2023-07-18 01:27:23    click_bottom_navigation_profile      9990864.0
# 8295448   2023-07-18 01:27:23                       view_lab_tap      9990864.0
# 8296133   2023-07-18 01:27:23    click_bottom_navigation_profile      9990864.0
# 14436091  2023-07-18 01:27:23                       view_lab_tap      9990864.0
# 14436405  2023-07-18 01:28:48                       view_lab_tap      9990864.0
# 8295762   2023-07-18 01:28:48                       view_lab_tap      9990864.0
# 8296269   2023-07-18 01:38:08                       $session_end      9990864.0
# 14436912  2023-07-18 01:38:08                       $session_end      9990864.0
# 8296017   2023-07-18 02:43:33                     $session_start      9990864.0
# 14436660  2023-07-18 02:43:33                     $session_start      9990864.0
# 8296175   2023-07-18 03:08:06        click_bottom_navigation_lab      9990864.0
# 14436818  2023-07-18 03:08:06        click_bottom_navigation_lab      9990864.0
# 14437000  2023-07-18 03:32:26                         launch_app      9990864.0
# 8296357   2023-07-18 03:32:26                         launch_app      9990864.0
# 14436911  2023-07-18 03:32:29                       view_lab_tap      9990891.0
# 14437105  2023-07-18 03:32:29        click_bottom_navigation_lab      9990891.0
# 8296268   2023-07-18 03:32:29                       view_lab_tap      9990891.0
# 8296462   2023-07-18 03:32:29        click_bottom_navigation_lab      9990891.0
# 8295765   2023-07-18 03:32:46                       $session_end      9990891.0
# 14436408  2023-07-18 03:32:46                       $session_end      9990891.0
# 8295490   2023-07-18 12:44:51                     $session_start      9990891.0
# 8296256   2023-07-18 12:44:51                         launch_app      9990891.0
# 14436133  2023-07-18 12:44:51                     $session_start      9990891.0
# 14436899  2023-07-18 12:44:51                         launch_app      9990891.0
# 14437043  2023-07-18 12:44:54        click_bottom_navigation_lab      9990891.0
# 14436265  2023-07-18 12:44:54                       view_lab_tap      9990891.0
# 8296400   2023-07-18 12:44:54        click_bottom_navigation_lab      9990891.0
# 8295622   2023-07-18 12:44:54                       view_lab_tap      9990891.0
# 8296329   2023-07-18 12:45:48                       $session_end      9990891.0
# 14436972  2023-07-18 12:45:48                       $session_end      9990891.0
# 8296110   2023-07-18 13:27:12                     $session_start      9990891.0
# 14436753  2023-07-18 13:27:12                     $session_start      9990891.0
# 8296442   2023-07-18 13:28:34                       $session_end      9990891.0
# 14437085  2023-07-18 13:28:34                       $session_end      9990891.0
# 8295603   2023-07-18 14:37:27                     $session_start      9990891.0
# 14436246  2023-07-18 14:37:27                     $session_start      9990891.0

# %%
# 다시 차이 계산
u["heart_diff"] = u["heart_balance"].diff()

u[["event_datetime", "event_key", "heart_balance", "heart_diff"]].head(50)
# Out:
#                event_datetime                          event_key  heart_balance  heart_diff
# 8295627   2023-07-18 00:24:39   click_bottom_navigation_timeline      9990864.0         NaN
# 14436270  2023-07-18 00:24:39   click_bottom_navigation_timeline      9990864.0         0.0
# 8295507   2023-07-18 00:24:40  click_bottom_navigation_questions      9990864.0         0.0
# 8295986   2023-07-18 00:24:40        click_bottom_navigation_lab      9990864.0         0.0
# 14436150  2023-07-18 00:24:40  click_bottom_navigation_questions      9990864.0         0.0
# 14436629  2023-07-18 00:24:40        click_bottom_navigation_lab      9990864.0         0.0
# 8295767   2023-07-18 00:24:41                       view_lab_tap      9990864.0         0.0
# 14436410  2023-07-18 00:24:41                       view_lab_tap      9990864.0         0.0
# 14436760  2023-07-18 01:02:29   click_bottom_navigation_timeline      9990864.0         0.0
# 14436537  2023-07-18 01:02:29  click_bottom_navigation_questions      9990864.0         0.0
# 8295894   2023-07-18 01:02:29  click_bottom_navigation_questions      9990864.0         0.0
# 8296117   2023-07-18 01:02:29   click_bottom_navigation_timeline      9990864.0         0.0
# 8295720   2023-07-18 01:02:30                       view_lab_tap      9990864.0         0.0
# 8295732   2023-07-18 01:02:30        click_bottom_navigation_lab      9990864.0         0.0
# 14436363  2023-07-18 01:02:30                       view_lab_tap      9990864.0         0.0
# 14436375  2023-07-18 01:02:30        click_bottom_navigation_lab      9990864.0         0.0
# 8296215   2023-07-18 01:27:11        click_bottom_navigation_lab      9990864.0         0.0
# 14436858  2023-07-18 01:27:11        click_bottom_navigation_lab      9990864.0         0.0
# 14436729  2023-07-18 01:27:15   click_bottom_navigation_timeline      9990864.0         0.0
# 8296086   2023-07-18 01:27:15   click_bottom_navigation_timeline      9990864.0         0.0
# 8296290   2023-07-18 01:27:17  click_bottom_navigation_questions      9990864.0         0.0
# 14436933  2023-07-18 01:27:17  click_bottom_navigation_questions      9990864.0         0.0
# 8295556   2023-07-18 01:27:18          click_appbar_alarm_center      9990864.0         0.0
# 14436199  2023-07-18 01:27:18          click_appbar_alarm_center      9990864.0         0.0
# 14436776  2023-07-18 01:27:23    click_bottom_navigation_profile      9990864.0         0.0
# 8295448   2023-07-18 01:27:23                       view_lab_tap      9990864.0         0.0
# 8296133   2023-07-18 01:27:23    click_bottom_navigation_profile      9990864.0         0.0
# 14436091  2023-07-18 01:27:23                       view_lab_tap      9990864.0         0.0
# 14436405  2023-07-18 01:28:48                       view_lab_tap      9990864.0         0.0
# 8295762   2023-07-18 01:28:48                       view_lab_tap      9990864.0         0.0
# 8296269   2023-07-18 01:38:08                       $session_end      9990864.0         0.0
# 14436912  2023-07-18 01:38:08                       $session_end      9990864.0         0.0
# 8296017   2023-07-18 02:43:33                     $session_start      9990864.0         0.0
# 14436660  2023-07-18 02:43:33                     $session_start      9990864.0         0.0
# 8296175   2023-07-18 03:08:06        click_bottom_navigation_lab      9990864.0         0.0
# 14436818  2023-07-18 03:08:06        click_bottom_navigation_lab      9990864.0         0.0
# 14437000  2023-07-18 03:32:26                         launch_app      9990864.0         0.0
# 8296357   2023-07-18 03:32:26                         launch_app      9990864.0         0.0
# 14436911  2023-07-18 03:32:29                       view_lab_tap      9990891.0        27.0
# 14437105  2023-07-18 03:32:29        click_bottom_navigation_lab      9990891.0         0.0
# 8296268   2023-07-18 03:32:29                       view_lab_tap      9990891.0         0.0
# 8296462   2023-07-18 03:32:29        click_bottom_navigation_lab      9990891.0         0.0
# 8295765   2023-07-18 03:32:46                       $session_end      9990891.0         0.0
# 14436408  2023-07-18 03:32:46                       $session_end      9990891.0         0.0
# 8295490   2023-07-18 12:44:51                     $session_start      9990891.0         0.0
# 8296256   2023-07-18 12:44:51                         launch_app      9990891.0         0.0
# 14436133  2023-07-18 12:44:51                     $session_start      9990891.0         0.0
# 14436899  2023-07-18 12:44:51                         launch_app      9990891.0         0.0
# 14437043  2023-07-18 12:44:54        click_bottom_navigation_lab      9990891.0         0.0
# 14436265  2023-07-18 12:44:54                       view_lab_tap      9990891.0         0.0

# %%
# 점프 구간만 확인
u[abs(u["heart_diff"]) >= 4000][
    ["event_datetime", "event_key", "heart_balance", "heart_diff"]
]
# Out:
#                event_datetime                        event_key  heart_balance  heart_diff
# 16323301  2023-07-19 01:00:49                       launch_app          766.0  -9990125.0
# 14436269  2023-07-19 01:46:42                   $session_start      9990891.0   9990125.0
# 16323299  2023-07-19 19:50:17                   $session_start          766.0  -9990125.0
# 8296035   2023-07-19 20:09:29                   $session_start      9990891.0   9990125.0
# 19400741  2023-07-20 16:00:50  click_bottom_navigation_profile          766.0  -9990125.0
# ...                       ...                              ...            ...         ...
# 14436653  2023-08-02 19:15:03                     $session_end      9991052.0   9894045.0
# 17439863  2023-08-02 19:16:56                     $session_end        97007.0  -9894045.0
# 8295630   2023-08-02 23:07:31                       launch_app      9991052.0   9894045.0
# 17439671  2023-08-03 20:57:31                       launch_app        97007.0  -9894045.0
# 14436605  2023-08-05 20:09:21                     $session_end      9991052.0   9895578.0
#
# [114 rows x 4 columns]
